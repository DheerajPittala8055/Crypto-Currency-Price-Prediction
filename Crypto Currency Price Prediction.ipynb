# %% [markdown]
# # <center> Crypto Currency Price Prediction

# %%
#importing libraries
import pandas as pd
import numpy as np
import statsmodels.api as smt
from matplotlib import pyplot as plt
from datetime import datetime as dt

#reading data into dataframes
bc = pd.read_csv("/content/BTC-USD-DEC.csv", index_col=0, parse_dates=True)
et = pd.read_csv("/content/ETH-USD _DEC1.csv",index_col=0,parse_dates=True)
dc = pd.read_csv("/content/DOGE-USD--DEC.csv",index_col=0,parse_dates=True)
usd = pd.read_csv("/content/US Dollar Index Futures Historical Data (1).csv", index_col=0, parse_dates=True)

# %%
#Bitcoin
bc
# Out:
#                     Open          High           Low         Close  \
# Date
# 2017-12-04  11315.400391  11657.200195  11081.799805  11657.200195
# 2017-12-05  11685.700195  12032.000000  11604.599609  11916.700195
# 2017-12-06  11923.400391  14369.099609  11923.400391  14291.500000
# 2017-12-07  14266.099609  17899.699219  14057.299805  17899.699219
# 2017-12-08  17802.900391  18353.400391  14336.900391  16569.400391
# ...                  ...           ...           ...           ...
# 2022-11-30  16445.476563  17190.937500  16445.476563  17168.566406
# 2022-12-01  17168.001953  17197.498047  16888.388672  16967.132813
# 2022-12-02  16968.683594  17088.660156  16877.880859  17088.660156
# 2022-12-03  17090.097656  17116.041016  16888.140625  16908.236328
# 2022-12-04  16905.757813  17127.470703  16905.757813  17085.908203
#
#                Adj Close       Volume
# Date
# 2017-12-04  11657.200195   6132409856
# 2017-12-05  11916.700195   6895260160
# 2017-12-06  14291.500000  12656300032
# 2017-12-07  17899.699219  17950699520
# 2017-12-08  16569.400391  21135998976
# ...                  ...          ...
# 2022-11-30  17168.566406  29523576583
# 2022-12-01  16967.132813  22895392882
# 2022-12-02  17088.660156  19539705127
# 2022-12-03  16908.236328  16217776704
# 2022-12-04  17085.908203  17693550592
#
# [1827 rows x 6 columns]

# %%
#Ethereum
et
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2017-12-04   466.053986   474.777008   453.312012   470.204010   470.204010
# 2017-12-05   470.294006   473.558014   457.660004   463.281006   463.281006
# 2017-12-06   462.604004   462.708008   420.209991   428.588013   428.588013
# 2017-12-07   426.368988   441.397003   414.411011   434.407990   434.407990
# 2017-12-08   434.989014   466.062012   422.367004   456.031006   456.031006
# ...                 ...          ...          ...          ...          ...
# 2022-12-01  1295.769531  1295.999878  1267.708496  1276.273926  1276.273926
# 2022-12-02  1276.328613  1294.303345  1269.243164  1294.303345  1294.303345
# 2022-12-03  1294.456543  1299.840332  1241.431885  1243.334839  1243.334839
# 2022-12-04  1243.219238  1281.492310  1242.911743  1280.256592  1280.256592
# 2022-12-05  1278.610840  1294.585571  1278.192627  1293.875244  1293.875244
#
#                 Volume
# Date
# 2017-12-04  1005550016
# 2017-12-05  1216720000
# 2017-12-06  1998259968
# 2017-12-07  2129570048
# 2017-12-08  2336379904
# ...                ...
# 2022-12-01  6857935276
# 2022-12-02  6213645709
# 2022-12-03  5672609405
# 2022-12-04  5174128454
# 2022-12-05  5272165376
#
# [1828 rows x 6 columns]

# %%
#Dogecoin
dc
# Out:
#                 Open      High       Low     Close  Adj Close      Volume
# Date
# 2017-12-04  0.002206  0.002475  0.002178  0.002463   0.002463     6307150
# 2017-12-05  0.002474  0.002676  0.002426  0.002479   0.002479     8772420
# 2017-12-06  0.002495  0.002663  0.002440  0.002663   0.002663     9047960
# 2017-12-07  0.002581  0.002858  0.002515  0.002720   0.002720    15759300
# 2017-12-08  0.002730  0.002846  0.002326  0.002779   0.002779    11797600
# ...              ...       ...       ...       ...        ...         ...
# 2022-11-30  0.101827  0.108942  0.100304  0.106860   0.106860  1388624554
# 2022-12-01  0.106857  0.107381  0.101071  0.101584   0.101584   891639200
# 2022-12-02  0.101594  0.103260  0.097639  0.102148   0.102148   776013992
# 2022-12-03  0.102150  0.102823  0.098651  0.099824   0.099824   632114946
# 2022-12-04  0.099905  0.105264  0.099905  0.103867   0.103867   775540864
#
# [1827 rows x 6 columns]

# %%
#US Dollar index featuring 
usd
# Out:
#               Price     Open     High      Low    Vol. Change %
# Date
# 2022-12-05  104.213  104.463  104.463  104.142       -   -0.27%
# 2022-12-02  104.500  104.795  105.575  103.935  43.74K   -0.18%
# 2022-12-01  104.689  105.570  105.860  104.550  43.75K   -1.14%
# 2022-11-30  105.897  106.660  107.150  105.710  37.35K   -0.82%
# 2022-11-29  106.768  106.605  106.820  105.995  24.38K    0.13%
# ...             ...      ...      ...      ...     ...      ...
# 2017-12-08   93.489   93.440   93.700   93.410   5.92K    0.08%
# 2017-12-07   93.414   93.235   93.425   93.150   2.48K    0.19%
# 2017-12-06   93.237   92.990   93.265   92.820   2.20K    0.25%
# 2017-12-05   93.004   92.720   93.100   92.695   2.19K    0.16%
# 2017-12-04   92.859   92.805   93.055   92.700   8.27K    0.34%
#
# [1293 rows x 6 columns]

# %%
#Information about bitcoin
bc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1827 entries, 2017-12-04 to 2022-12-04
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1827 non-null   float64
#  1   High       1827 non-null   float64
#  2   Low        1827 non-null   float64
#  3   Close      1827 non-null   float64
#  4   Adj Close  1827 non-null   float64
#  5   Volume     1827 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 99.9 KB

# %%
#information about ethereum
et.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1828 entries, 2017-12-04 to 2022-12-05
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1828 non-null   float64
#  1   High       1828 non-null   float64
#  2   Low        1828 non-null   float64
#  3   Close      1828 non-null   float64
#  4   Adj Close  1828 non-null   float64
#  5   Volume     1828 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 100.0 KB

# %%
#information about dogecoin
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1827 entries, 2017-12-04 to 2022-12-04
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1827 non-null   float64
#  1   High       1827 non-null   float64
#  2   Low        1827 non-null   float64
#  3   Close      1827 non-null   float64
#  4   Adj Close  1827 non-null   float64
#  5   Volume     1827 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 99.9 KB

# %%
#information about US Dollar index featuring
usd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1293 entries, 2022-12-05 to 2017-12-04
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Price     1293 non-null   float64
#  1   Open      1293 non-null   float64
#  2   High      1293 non-null   float64
#  3   Low       1293 non-null   float64
#  4   Vol.      1293 non-null   object
#  5   Change %  1293 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 70.7+ KB

# %%
#droping the unnecessary coloumns and keeping only date,close and volume
dc= dc.drop(dc.columns[[0,1,2,4]], axis=1)
dc.tail()
# Out:
#                Close      Volume
# Date
# 2022-11-30  0.106860  1388624554
# 2022-12-01  0.101584   891639200
# 2022-12-02  0.102148   776013992
# 2022-12-03  0.099824   632114946
# 2022-12-04  0.103867   775540864

# %%
#Droping all columns except date and price
usd = usd.drop(usd.columns[[1,2,3,4,5]], axis=1)
usd.head()
# Out:
#               Price
# Date
# 2022-12-05  104.213
# 2022-12-02  104.500
# 2022-12-01  104.689
# 2022-11-30  105.897
# 2022-11-29  106.768

# %%
print(dc.shape)
print(usd.shape)
# Out:
# (1827, 2)
# (1293, 1)

# %%
dc.describe()
# Out:
#              Close        Volume
# count  1827.000000  1.827000e+03
# mean      0.061264  1.035252e+09
# std       0.099445  3.520348e+09
# min       0.001537  2.134170e+06
# 25%       0.002605  2.939776e+07
# 50%       0.003768  1.087116e+08
# 75%       0.079796  7.119290e+08
# max       0.684777  6.941068e+10

# %%
usd.describe()
# Out:
#              Price
# count  1293.000000
# mean     96.164195
# std       5.034233
# min      88.170000
# 25%      92.886000
# 50%      95.777000
# 75%      97.594000
# max     114.047000

# %%
#joining usdollar index and dc
join = dc
for x in join.index:
    for x2 in usd.index:
        if x == x2:
            itemindex = np.where(usd.index==x2)[0][0]
            val = usd.at[x2, "Price"]
            join.at[x, 'Price'] = val
join.head()
# Out:
#                Close    Volume   Price
# Date
# 2017-12-04  0.002463   6307150  92.859
# 2017-12-05  0.002479   8772420  93.004
# 2017-12-06  0.002663   9047960  93.237
# 2017-12-07  0.002720  15759300  93.414
# 2017-12-08  0.002779  11797600  93.489

# %%
#renaming the coloums
join.rename(columns = {'Close':'dc_close_price', 'Volume':'Crypto_trade_volume', 'Price':'USD Price Index',}, inplace = True)
join.head()
# Out:
#             dc_close_price  Crypto_trade_volume  USD Price Index
# Date
# 2017-12-04        0.002463              6307150           92.859
# 2017-12-05        0.002479              8772420           93.004
# 2017-12-06        0.002663              9047960           93.237
# 2017-12-07        0.002720             15759300           93.414
# 2017-12-08        0.002779             11797600           93.489

# %%
#plotting the plots for join table
join = join.dropna()
join.plot(subplots=True, figsize=(12,8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa3051158e0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa30f087130>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fa305c9b970>],
#       dtype=object)

# %%
def plotcharts(y, title, lags=None, figsize=(12,8)):
    fig = plt.figure(figsize=figsize)
    layout = (2,2)
    ts_ax = plt.subplot2grid(layout, (0,0))
    hist_ax = plt.subplot2grid(layout, (0,1))
    acf_ax = plt.subplot2grid(layout, (1,0))
    pacf_ax = plt.subplot2grid(layout, (1,1))
    
    y.plot(ax=ts_ax)
    ts_ax.set_title(title, fontsize=14, fontweight="bold")
    y.plot(ax=hist_ax, kind="hist", bins=25)
    hist_ax.set_title("Histogram")
    smt.graphics.tsa.plot_acf(y, lags=lags, ax=acf_ax)
    smt.graphics.tsa.plot_pacf(y, lags=lags, ax=pacf_ax)
    [ax.set_xlim(0) for ax in [acf_ax, pacf_ax]]
    plt.tight_layout()
    return ts_ax, acf_ax, pacf_ax

# %%
series = join

# %%
#autocorrelating the close,volume and price
num_var = len(series.iloc[1,:])
for i in range(0, num_var):
    plotcharts(series.iloc[:,i].dropna(), title=series.columns[i], lags=48)

# %%
#log transformation
# Converting the data to a logarithmic scale
log = pd.DataFrame(np.log(series))

# Differencing the log values
#1
log_diff = log.diff().dropna()
#2
log_diff = log_diff.diff().dropna()
log_diff.plot(subplots=True)

#normalization
#importing minmaxscaler 
from sklearn.preprocessing import MinMaxScaler

#creating minmaxscaler object
norm = MinMaxScaler()

#applying norm to dataframe
join_norm = pd.DataFrame(norm.fit_transform(log_diff), columns=log_diff.columns)
join_norm
# Out:
#       dc_close_price  Crypto_trade_volume  USD Price Index
# 0           0.447824             0.439514         0.560187
# 1           0.406650             0.553673         0.534069
# 2           0.424717             0.363854         0.525824
# 3           0.419398             0.449085         0.527313
# 4           0.481425             0.692892         0.589202
# ...              ...                  ...              ...
# 1285        0.413076             0.377463         0.665813
# 1286        0.427172             0.437483         0.452246
# 1287        0.417354             0.487011         0.384518
# 1288        0.389473             0.415874         0.488902
# 1289        0.444634             0.523177         0.707437
#
# [1290 rows x 3 columns]

# %%
#autocorrelating 
num_var = len(join_norm.iloc[1,:])
for i in range(0, num_var):
    plotcharts(join_norm.iloc[:,i].dropna(), title=join_norm.columns[i], lags=48)
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/regression/linear_model.py:1434: RuntimeWarning:
#
# invalid value encountered in sqrt

# %%
from statsmodels.tsa.stattools import adfuller

def ad_test(dataset):
    dftest = adfuller(dataset, autolag= "AIC")
    print("1. ADF : ", dftest[0])
    print("2. P-Value : ", dftest[1])
    print("3. Num Of Lags : ", dftest[2])
    print("4. Num of Observations Used For ADF Regression and Critical Values Calculation : ", dftest[3])
    print("5. Critical Values : ")
    for key, val in dftest[4].items():
        print("\t", key, ": ", val)
        
ad_test(log_diff["dc_close_price"])
print("--------------------------------------------")
ad_test(log_diff["Crypto_trade_volume"])
print("--------------------------------------------")
ad_test(log_diff["USD Price Index"])
# Out:
# 1. ADF :  -13.446635596008859
# 2. P-Value :  3.7537724910826327e-25
# 3. Num Of Lags :  21
# 4. Num of Observations Used For ADF Regression and Critical Values Calculation :  1268
# 5. Critical Values :
# 	 1% :  -3.4355176558157616
# 	 5% :  -2.8638220694163588
# 	 10% :  -2.5679849962931267
# --------------------------------------------
# 1. ADF :  -14.765038998767022
# 2. P-Value :  2.3698178095610202e-27
# 3. Num Of Lags :  21
# 4. Num of Observations Used For ADF Regression and Critical Values Calculation :  1268
# 5. Critical Values :
# 	 1% :  -3.4355176558157616
# 	 5% :  -2.8638220694163588
# 	 10% :  -2.5679849962931267
# --------------------------------------------
# 1. ADF :  -13.880308374986347
# 2. P-Value :  6.228679343666984e-26
# 3. Num Of Lags :  22
# 4. Num of Observations Used For ADF Regression and Critical Values Calculation :  1267
# 5. Critical Values :
# 	 1% :  -3.4355217427788793
# 	 5% :  -2.8638238726872296
# 	 10% :  -2.5679859566283705

# %% [markdown]
# # **FB PROPHET**

# %%
#importing prophet 
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly

# %%
#fitting the model into prophet
def fit_model(df):
    m = Prophet(daily_seasonality=True)
    m.fit(df)
    future = m.make_future_dataframe(periods=365)
    forecast = m.predict(future)
    return m, forecast, future

def fb_plots(m, fore):
    return plot_plotly(m, forecast)

def fb_subplots(m, fore):
    return m.plot(forecast), m.plot_components(forecast)

# %%
#changing the columns as ds and y
bc = pd.read_csv("/content/BTC-USD-DEC.csv")
bc_price = bc.drop(bc.columns[[1,2,3,5,6]], axis=1)
bc_vol = bc.drop(bc.columns[[1,2,3,4,5]], axis=1)
bc_price.columns = ["ds","y"]
bc_vol.columns = ["ds","y"]
bc_price.head()
# Out:
#            ds             y
# 0  2017-12-04  11657.200195
# 1  2017-12-05  11916.700195
# 2  2017-12-06  14291.500000
# 3  2017-12-07  17899.699219
# 4  2017-12-08  16569.400391

# %%
#changing the columns as ds and y
et = pd.read_csv("/content/ETH-USD _DEC1.csv")
et_price = et.drop(et.columns[[1,2,3,5,6]], axis=1)
et_vol = et.drop(et.columns[[1,2,3,4,5]], axis=1)
et_price.columns = ["ds","y"]
et_price.head()
# Out:
#            ds           y
# 0  2017-12-04  470.204010
# 1  2017-12-05  463.281006
# 2  2017-12-06  428.588013
# 3  2017-12-07  434.407990
# 4  2017-12-08  456.031006

# %%
#changing the columns as ds and y
dc = pd.read_csv("/content/DOGE-USD--DEC.csv")
dc_price = dc.drop(dc.columns[[1,2,3,5,6]], axis=1)
dc_vol = dc.drop(dc.columns[[1,2,3,4,5]], axis=1)
dc_price.columns = ["ds","y"]
dc_price.head()
# Out:
#            ds         y
# 0  2017-12-04  0.002463
# 1  2017-12-05  0.002479
# 2  2017-12-06  0.002663
# 3  2017-12-07  0.002720
# 4  2017-12-08  0.002779

# %%
#choose any cryptocurrency you want to predict for one year
print("Codes for cryptos., Bitcoin - bc, Ethereum -et, Dogecoin -dc\n")
crypto = input("Enter the crypto type you want to predict\n")
if crypto == "bc":
  model, forecast, future =fit_model(bc_price)
elif crypto == "et":
  model, forecast, future =fit_model(et_price)
elif crypto == "dc":
  model, forecast, future =fit_model(dc_price)
else:
  print("Please enter the valid detail")
# Out:
# Codes for cryptos., Bitcoin - bc, Ethereum -et, Dogecoin -dc
#
# Enter the crypto type you want to predict
# dc
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp31fn18pp/boxjgbw8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp31fn18pp/ibo48ij0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=93469', 'data', 'file=/tmp/tmp31fn18pp/boxjgbw8.json', 'init=/tmp/tmp31fn18pp/ibo48ij0.json', 'output', 'file=/tmp/tmp31fn18pp/prophet_model0ywtbydg/prophet_model-20221206051453.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:14:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:14:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future.tail()
# Out:
#              ds
# 2187 2023-11-30
# 2188 2023-12-01
# 2189 2023-12-02
# 2190 2023-12-03
# 2191 2023-12-04

# %%
#forecasting the predection 
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 2187 2023-11-30 -0.126369   -0.270332    0.019101
# 2188 2023-12-01 -0.126723   -0.269681    0.013851
# 2189 2023-12-02 -0.128356   -0.267170    0.012581
# 2190 2023-12-03 -0.129750   -0.270917    0.017052
# 2191 2023-12-04 -0.132110   -0.277051    0.012353

# %%
#plotting the graph for forecasted data
fb_plots(model, forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="10b41544-c0de-4c3e-9aa7-74b8a6d48de0" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10b41544-c0de-4c3e-9aa7-74b8a6d48de0")) {                    Plotly.newPlot(                        "10b41544-c0de-4c3e-9aa7-74b8a6d48de0",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2017-12-04T00:00:00","2017-12-05T00:00:00","2017-12-06T00:00:00","2017-12-07T00:00:00","2017-12-08T00:00:00","2017-12-09T00:00:00","2017-12-10T00:00:00","2017-12-11T00:00:00","2017-12-12T00:00:00","2017-12-13T00:00:00","2017-12-14T00:00:00","2017-12-15T00:00:00","2017-12-16T00:00:00","2017-12-17T00:00:00","2017-12-18T00:00:00","2017-12-19T00:00:00","2017-12-20T00:00:00","2017-12-21T00:00:00","2017-12-22T00:00:00","2017-12-23T00:00:00","2017-12-24T00:00:00","2017-12-25T00:00:00","2017-12-26T00:00:00","2017-12-27T00:00:00","2017-12-28T00:00:00","2017-12-29T00:00:00","2017-12-30T00:00:00","2017-12-31T00:00:00","2018-01-01T00:00:00","2018-01-02T00:00:00","2018-01-03T00:00:00","2018-01-04T00:00:00","2018-01-05T00:00:00","2018-01-06T00:00:00","2018-01-07T00:00:00","2018-01-08T00:00:00","2018-01-09T00:00:00","2018-01-10T00:00:00","2018-01-11T00:00:00","2018-01-12T00:00:00","2018-01-13T00:00:00","2018-01-14T00:00:00","2018-01-15T00:00:00","2018-01-16T00:00:00","2018-01-17T00:00:00","2018-01-18T00:00:00","2018-01-19T00:00:00","2018-01-20T00:00:00","2018-01-21T00:00:00","2018-01-22T00:00:00","2018-01-23T00:00:00","2018-01-24T00:00:00","2018-01-25T00:00:00","2018-01-26T00:00:00","2018-01-27T00:00:00","2018-01-28T00:00:00","2018-01-29T00:00:00","2018-01-30T00:00:00","2018-01-31T00:00:00","2018-02-01T00:00:00","2018-02-02T00:00:00","2018-02-03T00:00:00","2018-02-04T00:00:00","2018-02-05T00:00:00","2018-02-06T00:00:00","2018-02-07T00:00:00","2018-02-08T00:00:00","2018-02-09T00:00:00","2018-02-10T00:00:00","2018-02-11T00:00:00","2018-02-12T00:00:00","2018-02-13T00:00:00","2018-02-14T00:00:00","2018-02-15T00:00:00","2018-02-16T00:00:00","2018-02-17T00:00:00","2018-02-18T00:00:00","2018-02-19T00:00:00","2018-02-20T00:00:00","2018-02-21T00:00:00","2018-02-22T00:00:00","2018-02-23T00:00:00","2018-02-24T00:00:00","2018-02-25T00:00:00","2018-02-26T00:00:00","2018-02-27T00:00:00","2018-02-28T00:00:00","2018-03-01T00:00:00","2018-03-02T00:00:00","2018-03-03T00:00:00","2018-03-04T00:00:00","2018-03-05T00:00:00","2018-03-06T00:00:00","2018-03-07T00:00:00","2018-03-08T00:00:00","2018-03-09T00:00:00","2018-03-10T00:00:00","2018-03-11T00:00:00","2018-03-12T00:00:00","2018-03-13T00:00:00","2018-03-14T00:00:00","2018-03-15T00:00:00","2018-03-16T00:00:00","2018-03-17T00:00:00","2018-03-18T00:00:00","2018-03-19T00:00:00","2018-03-20T00:00:00","2018-03-21T00:00:00","2018-03-22T00:00:00","2018-03-23T00:00:00","2018-03-24T00:00:00","2018-03-25T00:00:00","2018-03-26T00:00:00","2018-03-27T00:00:00","2018-03-28T00:00:00","2018-03-29T00:00:00","2018-03-30T00:00:00","2018-03-31T00:00:00","2018-04-01T00:00:00","2018-04-02T00:00:00","2018-04-03T00:00:00","2018-04-04T00:00:00","2018-04-05T00:00:00","2018-04-06T00:00:00","2018-04-07T00:00:00","2018-04-08T00:00:00","2018-04-09T00:00:00","2018-04-10T00:00:00","2018-04-11T00:00:00","2018-04-12T00:00:00","2018-04-13T00:00:00","2018-04-14T00:00:00","2018-04-15T00:00:00","2018-04-16T00:00:00","2018-04-17T00:00:00","2018-04-18T00:00:00","2018-04-19T00:00:00","2018-04-20T00:00:00","2018-04-21T00:00:00","2018-04-22T00:00:00","2018-04-23T00:00:00","2018-04-24T00:00:00","2018-04-25T00:00:00","2018-04-26T00:00:00","2018-04-27T00:00:00","2018-04-28T00:00:00","2018-04-29T00:00:00","2018-04-30T00:00:00","2018-05-01T00:00:00","2018-05-02T00:00:00","2018-05-03T00:00:00","2018-05-04T00:00:00","2018-05-05T00:00:00","2018-05-06 ...

# %%
#ploting the subplots fro forecasted data
fb_subplots(model, forecast)
# Out:
# (<Figure size 720x432 with 1 Axes>, <Figure size 648x864 with 4 Axes>)

# %%
#Cross Validation
from prophet.diagnostics import cross_validation
bc_cv = cross_validation(model, initial='730 days', period='180 days', horizon = '365 days')
bc_cv.tail()
# Out:
# INFO:prophet:Making 5 forecasts with cutoffs between 2019-12-15 00:00:00 and 2021-12-04 00:00:00
#   0%|          | 0/5 [00:00<?, ?it/s]
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp31fn18pp/c1j7c80k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp31fn18pp/q3bnvqu2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=55243', 'data', 'file=/tmp/tmp31fn18pp/c1j7c80k.json', 'init=/tmp/tmp31fn18pp/q3bnvqu2.json', 'output', 'file=/tmp/tmp31fn18pp/prophet_modelvsg5_1fz/prophet_model-20221206051548.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:15:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:15:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp31fn18pp/oxndzeiz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp31fn18pp/3g7sra8g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35700', 'data', 'file=/tmp/tmp31fn18pp/oxndzeiz.json', 'init=/tmp/tmp31fn18pp/3g7sra8g.json', 'output', 'file=/tmp/tmp31fn18pp/prophet_modelcpj5tll5/prophet_model-20221206051549.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:15:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:15:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp31fn18pp/dkpw3gy5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp31fn18pp/p2qbrpd8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98324', 'data', 'file=/tmp/tmp31fn18pp/dkpw3gy5.json', 'init=/tmp/tmp31fn18pp/p2qbrpd8.json', 'output', 'file=/tmp/tmp31fn18pp/prophet_model1b0ysp7e/prophet_model-20221206051550.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:15:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:15:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp31fn18pp/exk6leu2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp31fn18pp/40pvb81e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28707', 'data', 'file=/tmp/tmp31fn18pp/exk6leu2.json', 'init=/tmp/tmp31fn18pp/40pvb81e.json', 'output', 'file=/tmp/tmp31fn18pp/prophet_modelrb7kyrd9/prophet_model-20221206051551.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:15:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:15:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp31fn18pp/6tlxd_wy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp31fn18pp/vloxkrig.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.8/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42709', 'data', 'file=/tmp/tmp31fn18pp/6tlxd_wy.json', 'init=/tmp/tmp31fn18pp/vloxkrig.json', 'output', 'file=/tmp/tmp31fn18pp/prophet_model4sjhygl8/prophet_model-20221206051552.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:15:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:15:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#              ds      yhat  yhat_lower  yhat_upper         y     cutoff
# 1820 2022-11-30  0.566596    0.482001    0.643774  0.106860 2021-12-04
# 1821 2022-12-01  0.568255    0.484216    0.645301  0.101584 2021-12-04
# 1822 2022-12-02  0.571057    0.488399    0.652535  0.102148 2021-12-04
# 1823 2022-12-03  0.572132    0.492171    0.650131  0.099824 2021-12-04
# 1824 2022-12-04  0.574412    0.488742    0.660517  0.103867 2021-12-04

# %%
#performance metrics
from prophet.diagnostics import performance_metrics
bc_p = performance_metrics(bc_cv)
bc_p.head()
# Out:
#   horizon       mse      rmse       mae      mape     mdape     smape  \
# 0 37 days  0.006445  0.080279  0.047338  0.490323  0.540057  0.434692
# 1 38 days  0.006704  0.081876  0.048469  0.495359  0.540057  0.435644
# 2 39 days  0.006981  0.083553  0.049678  0.501204  0.542963  0.437518
# 3 40 days  0.007216  0.084947  0.050834  0.506639  0.542963  0.440248
# 4 41 days  0.007434  0.086223  0.051965  0.512403  0.553416  0.444088
#
#    coverage
# 0  0.380220
# 1  0.374725
# 2  0.369231
# 3  0.363736
# 4  0.358242

# %%
#plotting the cross validation
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(bc_cv, metric='mape')
# Out:
# /usr/local/lib/python3.8/dist-packages/prophet/plot.py:544: FutureWarning:
#
# casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.
#
# /usr/local/lib/python3.8/dist-packages/prophet/plot.py:545: FutureWarning:
#
# casting timedelta64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.

# %%
#convert dataset into csv file
forecast.to_csv('bitcoin_forecast.csv')

#download dataset
from google.colab import files
files.download('bitcoin_forecast.csv')

# %% [markdown]
# # ***Support Vector Machine***

# %%
#importing the libraries
import numpy as np
import pandas_datareader as web
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
#plotting the graph close and usd close price
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(dc['Close'])
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.show()

# %%
dc = dc[['Close']]
print(dc.head())
# Out:
#       Close
# 0  0.002463
# 1  0.002479
# 2  0.002663
# 3  0.002720
# 4  0.002779

# %%
dc.dropna(inplace=True)

# %%
forecast_out = 30
dc['Prediction'] = dc[['Close']].shift(-forecast_out)
print(dc.tail())
# Out:
#          Close  Prediction
# 1822  0.106860         NaN
# 1823  0.101584         NaN
# 1824  0.102148         NaN
# 1825  0.099824         NaN
# 1826  0.103867         NaN

# %%
X = np.array(dc.drop(['Prediction'],1))
X = X[:-forecast_out]
print(X)
# Out:
# [[0.002463]
#  [0.002479]
#  [0.002663]
#  ...
#  [0.12783 ]
#  [0.122592]
#  [0.12628 ]]
# <ipython-input-232-4a4198f03340>:1: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
y = np.array(dc['Prediction'])
y = y[:-forecast_out]
print(y)
# Out:
# [0.00932  0.009644 0.012167 ... 0.102148 0.099824 0.103867]

# %%
#splitting the data into training and testing data
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=44)

# %%
svr_rbf = SVR(kernel='rbf', C=1e3, gamma=0.1)
svr_rbf.fit(x_train, y_train)
# Out:
# SVR(C=1000.0, gamma=0.1)

# %%
x_forecast = np.array(dc.drop(['Prediction'],1))[-forecast_out:]
print(x_forecast)
# Out:
# [[0.124388]
#  [0.114606]
#  [0.111299]
#  [0.08841 ]
#  [0.074288]
#  [0.089789]
#  [0.084885]
#  [0.088039]
#  [0.084893]
#  [0.085879]
#  [0.086971]
#  [0.085583]
#  [0.084765]
#  [0.084672]
#  [0.084581]
#  [0.077174]
#  [0.074711]
#  [0.078488]
#  [0.081786]
#  [0.081481]
#  [0.089475]
#  [0.088988]
#  [0.098712]
#  [0.095122]
#  [0.101853]
#  [0.10686 ]
#  [0.101584]
#  [0.102148]
#  [0.099824]
#  [0.103867]]
# <ipython-input-236-3cfe6ca733a6>:1: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
import math
data = dc.filter(['Close'])
dataset = data.values
training_data_len = math.ceil( len(dataset) * .8 )
training_data_len
# Out:
# 1462

# %%
#plotting the graph for predicted values
train = dc[:training_data_len]
valid = dc[training_data_len:]
plt.figure(figsize=(16,8))
plt.title('Model')
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train['Close'])
plt.plot(valid[['Close']])
plt.legend(['Train', 'Predictions'], loc='lower right')
plt.show()

# %%
# Predicting the target values of the test set
from sklearn.metrics import mean_squared_error
y_forecast = svr_rbf.predict(x_test)
# RMSE (Root Mean Square Error)
rmse = float(format(np.sqrt(mean_squared_error(y_test,y_forecast)), '.3f'))
print("\nRMSE: ", rmse)
# Out:
# RMSE:  0.093
